# %%
# Remember to install these libraries before running code
# pip install pandas
# pip install matplotlib
# pip install seaborn
# pip install sankeyflow

# %%
#************************Histogram************************

import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Creating arbitrary dataset from random numbers
np.random.seed(1)
numb_var = np.random.randn(1200)
numb_var = pd.Series(numb_var, name = "Numerical Measures")

# Plotting the histogram
sns.histplot(data = numb_var, kde=True)
plt.show()

#************************Boxplot************************
df = sns.load_dataset('tips')

# Creating our first boxplot
sns.boxplot(data=df, x='day', y='total_bill')
plt.show()
